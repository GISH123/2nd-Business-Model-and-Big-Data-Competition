# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500) 
merged = pd.read_csv('y = last month(without redundant).csv')

# %%
predy1 = pd.read_csv('submit_pred_proba_y1(threshold = 0.62).csv',header=None)

# %%
predy2 = pd.read_csv('submit_pred_proba_y2(threshold = 0.9).csv',header=None)

# %%
predy1.columns = ['y1']

# %%
#predy1[predy1['y1'] == 1]

# %%
predy2.columns = ['y2']

# %%
#predy2[predy2['y2'] == 1]

# %%
srno_series = pd.Series(merged['srno'].unique())

# %%
combination = pd.concat([srno_series,predy1, predy2], axis=1)

# %%
#combination[combination['y2']==1]
# Out:
#                0   y1   y2
# 588        96929  0.0  1.0
# 2684      174223  0.0  1.0
# 2899      180707  0.0  1.0
# 3174      188173  0.0  1.0
# 3253      190358  0.0  1.0
# 3320      192229  0.0  1.0
# 3321      192293  0.0  1.0
# 3324      192406  0.0  1.0
# 3501      198338  0.0  1.0
# 3556      199890  0.0  1.0
# 3640      201749  0.0  1.0
# 3702      203747  0.0  1.0
# 3735      205138  0.0  1.0
# 7484      324742  0.0  1.0
# 9042      458227  0.0  1.0
# 10525     480167  0.0  1.0
# 11466     497520  0.0  1.0
# 12467     546802  0.0  1.0
# 12592     550123  0.0  1.0
# 12722     553648  1.0  1.0
# 12948     569764  0.0  1.0
# 13195     575069  0.0  1.0
# 14563     600157  0.0  1.0
# 17168     701711  0.0  1.0
# 20424     887532  0.0  1.0
# 23181     978161  0.0  1.0
# 23333     984054  0.0  1.0
# 23448     988140  0.0  1.0
# 23513     990076  0.0  1.0
# 23549     990904  0.0  1.0
# ...          ...  ...  ...
# 233509  10972402  0.0  1.0
# 233526  10974354  0.0  1.0
# ...

# %%
combination.columns = ['srno','y1','y2']

# %%
#combination[combination['y2']==1]

# %%
combination.to_csv('submission.csv',index=False)
